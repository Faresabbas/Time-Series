# %% [markdown]
# ## Time Series - Programming Languages
#
#
# ## Python
# It is a high-level interpreted programming language, fast and easy to code. Python can follow either procedural or object-oriented programming paradigms. The presence of a variety of libraries makes implementation of complicated procedures simpler. In this tutorial, we will be coding in Python and the corresponding libraries useful for time series modelling will be discussed in the upcoming chapters.
#
# ## R
# Similar to Python, R is an interpreted multi-paradigm language, which supports statistical computing and graphics. The variety of packages makes it easier to implement machine learning modelling in R.
#
# ## Java
# It is an interpreted object-oriented programming language, which is widely famous for a large range of package availability and sophisticated data visualization techniques.
#
# ## C/C++
#
# These are compiled languages, and two of the oldest programming languages. These languages are often preferred to incorporate ML capabilities in the already existing applications as they allow you to customize the implementation of ML algorithms easily.
#
# ## MATLAB
#
# MATrix LABoratory is a multi-paradigm language which gives functioning to work with matrices. It allows mathematical operations for complex problems. It is primarily used for numerical operations but some packages also allow the graphical multi-domain simulation and model-based design.
#
# Other preferred programming languages for machine learning problems include JavaScript, LISP, Prolog, SQL, Scala, Julia, SAS etc.

# %% [markdown]
# ## ************************************************

# %% [markdown]
# ## Time Series - Python Libraries
#
#
# ## Scikit Learn
#
#
# This library is a SciPy Toolkit widely used for statistical modelling, machine learning and deep learning, as it contains various customizable regression, classification and clustering models. It works well with Numpy, Pandas and other libraries which makes it easier to use.
#
# ## Statsmodels
# Like Scikit Learn, this library is used for statistical data exploration and statistical modelling. It also operates well with other Python libraries.
#
# ## Matplotlib
#
# This library is used for data visualization in various formats such as line plot, bar graph, heat maps, scatter plots, histogram etc. It contains all the graph related functionalities required from plotting to labelling. We will discuss these functionalities as we move ahead in this tutorial.
# These libraries are very essential to start with machine learning with any sort of data.
# Beside the ones discussed above, another library especially significant to deal with time series is −
#
# ## Datetime
#
# This library, with its two modules − datetime and calendar, provides all necessary datetime functionality for reading, formatting and manipulating time.

# %% [markdown]
# ## *********************************************

# %% [markdown]
# ## Time Series - Data Processing and Visualization

# %%
import pandas as pd

# %%
pd.to_datetime('2-4-2020',dayfirst=True)
# Out:
# Timestamp('2020-04-02 00:00:00')

# %%
opsd_daily = pd.read_csv(r'F:\SKlearn_files-master\SKlearn_files-master\Data\4 Time Series\opsd_germany_daily.csv')
opsd_daily.shape
# Out:
# (4383, 5)

# %%
opsd_daily.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %%
opsd_daily.tail()
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156

# %%
opsd_daily = opsd_daily.set_index('Date')
opsd_daily.head(3)
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN

# %%
opsd_daily = pd.read_csv(r'F:\SKlearn_files-master\SKlearn_files-master\Data\4 Time Series\opsd_germany_daily.csv', index_col=0,
                         parse_dates=True)

# %%
opsd_daily
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %%
# Add columns with year, month, and weekday name
opsd_daily['Year'] = opsd_daily.index.year
opsd_daily['Month'] = opsd_daily.index.month
opsd_daily['Weekday Name'] = opsd_daily.index.weekday
# Display a random sampling of 5 rows
opsd_daily.sample(5, random_state=0)
# Out:
#             Consumption    Wind    Solar  Wind+Solar  Year  Month  \
# Date
# 2008-08-23     1152.011     NaN      NaN         NaN  2008      8
# 2013-08-08     1291.984  79.666   93.371     173.037  2013      8
# 2009-08-27     1281.057     NaN      NaN         NaN  2009      8
# 2015-10-02     1391.050  81.229  160.641     241.870  2015     10
# 2009-06-02     1201.522     NaN      NaN         NaN  2009      6
#
#             Weekday Name
# Date
# 2008-08-23             5
# 2013-08-08             3
# 2009-08-27             3
# 2015-10-02             4
# 2009-06-02             1

# %%
opsd_daily.loc['2017-08-10']
opsd_daily.loc['2014-01-20':'2014-01-22']
opsd_daily.loc['2012-02']
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month  \
# Date
# 2012-02-01     1511.866  199.607  43.502     243.109  2012      2
# 2012-02-02     1563.407   73.469  44.675     118.144  2012      2
# 2012-02-03     1563.631   36.352  46.510      82.862  2012      2
# 2012-02-04     1372.614   20.551  45.225      65.776  2012      2
# 2012-02-05     1279.432   55.522  54.572     110.094  2012      2
# 2012-02-06     1574.766   34.896  55.389      90.285  2012      2
# 2012-02-07     1615.078  100.312  19.867     120.179  2012      2
# 2012-02-08     1613.774   93.763  36.930     130.693  2012      2
# 2012-02-09     1591.532  132.219  19.042     151.261  2012      2
# 2012-02-10     1581.287   52.122  34.873      86.995  2012      2
# 2012-02-11     1377.404   32.375  44.629      77.004  2012      2
# 2012-02-12     1264.254   62.659  45.176     107.835  2012      2
# 2012-02-13     1561.987   25.984  11.287      37.271  2012      2
# 2012-02-14     1550.366  146.495   9.610     156.105  2012      2
# 2012-02-15     1476.037  413.367  18.877     432.244  2012      2
# 2012-02-16     1504.119  130.247  38.176     168.423  2012      2
# 2012-02-17     1438.857  196.515  17.328     213.843  2012      2
# 2012-02-18     1236.069  237.889  26.248     264.137  2012      2
# 2012-02-19     1107.431  272.655  30.382     303.037  2012      2
# 2012-02-20     1401.873  160.315  53.794     214.109  2012      2
# 2012-02-21     1434.533  281.909  57.984     339.893  2012      2
# 2012-02-22     1453.507  287.635  74.904     362.539  2012      2
# 2012-02-23     1427.402  353.510  18.927     372.437  2012      2
# 2012-02-24     1373.800  382.777  29.281     412.058  2012      2
# 2012-02-25     1133.184  302.102  42.667     344.769  2012      2
# 2012-02-26     1086.743   95.234  37.214     132.448  2012      2
# 2012-02-27     1436.095   86.956  43.099     130.055  2012      2
# 2012-02-28     1408.211  231.923  16.190     248.113  2012      2
# 2012-02-29     1434.062   77.024  30.360     107.384  2012      2
#
#             Weekday Name
# Date
# 2012-02-01             2
# 2012-02-02             3
# 2012-02-03             4
# 2012-02-04             5
# 2012-02-05             6
# 2012-02-06             0
# 2012-02-07             1
# 2012-02-08             2
# 2012-02-09             3
# 2012-02-10             4
# 2012-02-11             5
# 2012-02-12             6
# 2012-02-13             0
# 2012-02-14             1
# 2012-02-15             2
# 2012-02-16             3
# 2012-02-17             4
# 2012-02-18             5
# 2012-02-19             6
# 2012-02-20             0
# 2012-02-21             1
# 2012-02-22             2
# 2012-02-23             3
# 2012-02-24             4
# 2012-02-25             5
# 2012-02-26             6
# 2012-02-27             0
# 2012-02-28             1
# 2012-02-29             2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(15,15)})
opsd_daily['Consumption'].plot(linewidth=0.5)

# %%
opsd_daily['Solar'].plot(linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
opsd_daily['Wind'].plot(linewidth=0.5)

# %%
cols_plot = ['Consumption', 'Solar', 'Wind']
axes = opsd_daily[cols_plot].plot(marker='.', alpha=0.5,  
                 figsize=(15,15), subplots=True)

# %%
ax = opsd_daily.loc['2011', 'Consumption'].plot()
ax.set_ylabel('Daily Consumption')
ax = opsd_daily.loc['2011-10':'2011-12', 'Consumption'].plot(marker='o', linestyle='--')
ax.set_ylabel('Daily Consumption')

# %%
ax = opsd_daily.loc['2015', 'Solar'].plot()
ax.set_ylabel('Daily Solar'

ax = opsd_daily.loc['2015-05':'2015-09', 'Solar'].plot(marker='o', linestyle='-')
ax.set_ylabel('Daily Solar')

# %%
fig, ax = plt.subplots()
ax.plot(opsd_daily.loc['2012-01':'2012-02', 'Consumption'], marker='o', linestyle='-')
ax.set_ylabel('Daily Consumption')
ax.set_title('Jan-Feb 2017 Electricity Consumption')
# Out:
# Text(0.5, 1.0, 'Jan-Feb 2017 Electricity Consumption')

# %%
fig, ax = plt.subplots()
ax.plot(opsd_daily.loc['2012-01':'2012-05', 'Wind'], marker='o', linestyle='-')
ax.set_ylabel('Daily Wind')
ax.set_title(' Electricity Wind')
# Out:
# Text(0.5, 1.0, ' Electricity Wind')
